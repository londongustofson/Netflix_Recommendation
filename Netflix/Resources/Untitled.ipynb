# %%
import pandas as pd

# %%
movies_df = pd.read_csv("Movies.csv")
movies_df.head()
# Out:
#    movie_ID                               Title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         Genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings_df = pd.read_csv("ratings.csv")
ratings_df.head()
# Out:
#      Column  user_ID  movie_ID  rating   timestamp
# 0  15147342   104679       370     4.0  1316200244
# 1    658718     4374      1124     4.0   962918551
# 2   7356723    50749      8798     3.5  1349529481
# 3  16533607   114406     55031     0.5  1290917884
# 4   7914912    54510      2987     3.0  1209265378

# %%
merge_table = pd.merge(ratings_df, movies_df, on="movie_ID")
merge_table
# Out:
#           Column  user_ID  movie_ID  rating   timestamp  \
# 0       15147342   104679       370     4.0  1316200244
# 1        6553742    45058       370     4.0   838727919
# 2        5177168    35444       370     4.0   840209053
# 3         937179     6291       370     2.0  1036037895
# 4        6842313    47111       370     3.0   839764375
# 5       19597276   135667       370     2.5  1084780607
# 6        2955464    20100       370     3.0   854376708
# 7        1146629     7817       370     0.5  1111430052
# 8        1130287     7714       370     3.5  1212580033
# 9       14521494   100356       370     0.5  1374933915
# 10      15054579   103973       370     1.5  1207634755
# 11      13341599    92208       370     4.0   848487809
# 12       5353932    36743       370     3.0   875314270
# 13       9957898    68809       370     4.0   852483291
# 14      19234193   133094       370     3.0   837944988
# 15      16299583   112843       370     1.0   974926285
# ...

# %%
dummy_df = pd.get_dummies(aisle_df.aisle)dummy_df = pd.concat([merge_table, dummy_df], axis=1)
dummy_df = aisle_dummy_df.drop(['movie_ID'], axis=1)
dummy_df.head()
# Out:
#   File "<ipython-input-6-da12830db748>", line 1
#     dummy_df = pd.get_dummies(aisle_df.aisle)dummy_df = pd.concat([merge_table, dummy_df], axis=1)
#                                                     ^
# SyntaxError: invalid syntax
